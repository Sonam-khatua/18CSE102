# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib','inline')
plt.style.use('seaborn-whitegrid')

# %%
dataset=pd.read_csv("diabetes.csv")

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
data=dataset[['Pregnancies','BloodPressure']]

# %%
data.head()
# Out:
#    Pregnancies  BloodPressure
# 0            6             72
# 1            1             66
# 2            8             64
# 3            1             66
# 4            0             40

# %%
x=data['Pregnancies']
y=data['BloodPressure']

# %%
sns.lineplot(x,y,dashes=True)
plt.show()

# %%
from scipy.stats import norm

# %%
correlation=data.corr()
print(correlation)
# Out:
#                Pregnancies  BloodPressure
# Pregnancies       1.000000       0.141282
# BloodPressure     0.141282       1.000000

# %%
sns.heatmap(correlation,cmap='BrBG')
plt.show()

# %%
covar=data.cov()
print(covar)
# Out:
#                Pregnancies  BloodPressure
# Pregnancies      11.354056       9.214538
# BloodPressure     9.214538     374.647271

# %%
sns.heatmap(covar)
plt.show()

# %%
#Normalization

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
dataset.shape
# Out:
# (768, 9)

# %%
Age=np.array(dataset['Age'])

# %%
Age
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 30, 34, 57, 59, 51, 32, 31,
#        31, 33, 32, 27, 50, 41, 29, 51, 41, 43, 22, 57, 38, 60, 28, 22, 28,
#        45, 33, 35, 46, 27, 56, 26, 37, 48, 54, 40, 25, 29, 22, 31, 24, 22,
#        26, 30, 58, 42, 21, 41, 31, 44, 22, 21, 39, 36, 24, 42, 32, 38, 54,
#        25, 27, 28, 26, 42, 23, 22, 22, 41, 27, 26, 24, 22, 22, 36, 22, 37,
#        27, 45, 26, 43, 24, 21, 34, 42, 60, 21, 40, 24, 22, 23, 31, 33, 22,
#        21, 24, 27, 21, 27, 37, 25, 24, 24, 46, 23, 25, 39, 61, 38, 25, 22,
#        21, 25, 24, 23, 69, 23, 26, 30, 23, 40, 62, 33, 33, 30, 39, 26, 31,
#        21, 22, 29, 28, 55, 38, 22, 42, 23, 21, 41, 34, 65, 22, 24, 37, 42,
#        23, 43, 36, 21, 23, 22, 47, 36, 45, 27, 21, 32, 41, 22, 34, 29, 29,
#        36, 29, 25, 23, 33, 36, 42, 26, 47, 37, 32, 23, 21, 27, 40, 41, 60,
#        33, 31, 25, 21, 40, 36, 40, 42, 29, 21, 23, 26, 29, 21, 28, 32, 27,
# ...

# %%
Age=np.array(dataset['Age'])
print("max Age",max(Age))
Age=Age.reshape(768,1)
# Out:
# max Age 81

# %%
Age=np.array(dataset['Age'])
print("max Age",max(Age))
Age=Age.reshape(768,1)
# Out:
# max Age 81

# %%
from scipy import stats
zscore=np.array(stats.zscore(Age))
zscore=zscore[0:394]
zscore=zscore.reshape(2,197)

# %%
zscore
# Out:
# array([[ 1.4259954 , -0.19067191, -0.10558415, -1.04154944, -0.0204964 ,
#         -0.27575966, -0.61611067, -0.36084741,  1.68125866,  1.76634642,
#         -0.27575966,  0.06459135,  2.02160968,  2.19178518,  1.51108316,
#         -0.10558415, -0.19067191, -0.19067191, -0.0204964 , -0.10558415,
#         -0.53102292,  1.4259954 ,  0.66020563, -0.36084741,  1.51108316,
#          0.66020563,  0.83038113, -0.95646168,  2.02160968,  0.40494237,
#          2.27687294, -0.44593516, -0.95646168, -0.44593516,  1.00055664,
#         -0.0204964 ,  0.14967911,  1.08564439, -0.53102292,  1.93652192,
#         -0.61611067,  0.31985461,  1.2558199 ,  1.76634642,  0.57511787,
#         -0.70119842, -0.36084741, -0.95646168, -0.19067191, -0.78628618,
#         -0.95646168, -0.61611067, -0.27575966,  2.10669743,  0.74529338,
#         -1.04154944,  0.66020563, -0.19067191,  0.91546889, -0.95646168,
#         -1.04154944,  0.49003012,  0.23476686, -0.78628618,  0.74529338,
# ...

# %%
#Decimal Normalization

# %%
dn=[]
dn.append(Age/pow(10,2) )
dn=np.array(dn)

# %%
dn
# Out:
# array([[[0.5 ],
#         [0.31],
#         [0.32],
#         [0.21],
#         [0.33],
#         [0.3 ],
#         [0.26],
#         [0.29],
#         [0.53],
#         [0.54],
#         [0.3 ],
#         [0.34],
#         [0.57],
#         [0.59],
#         [0.51],
#         [0.32],
#         [0.31],
#         [0.31],
#         [0.33],
#         [0.32],
#         [0.27],
#         [0.5 ],
#         [0.41],
#         [0.29],
#         [0.51],
#         [0.41],
#         [0.43],
#         [0.22],
#         [0.57],
#         [0.38],
#         [0.6 ],
#         [0.28],
#         [0.22],
#         [0.28],
#         [0.45],
#         [0.33],
#         [0.35],
#         [0.46],
#         [0.27],
#         [0.56],
#         [0.26],
#         [0.37],
#         [0.48],
#         [0.54],
#         [0.4 ],
#         [0.25],
#         [0.29],
#         [0.22],
#         [0.31],
#         [0.24],
#         [0.22],
#         [0.26],
#         [0.3 ],
#         [0.58],
#         [0.42],
# ...
